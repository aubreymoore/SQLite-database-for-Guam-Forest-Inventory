# %% [markdown]
# # Analysis of Guam Forest Inventory Survey Data
#
# This iPython notebook creates an SQLite database containing US Forest Service Forest Inventory data collected on Guam in 2002 and 2013.
#
# The Forest Service has kindly provided online access to data from its national forest inventory surveys on its [FIA DataMart](http://apps.fs.fed.us/fiadb-downloads/datamart.html) page. Data are available as Microsoft Access databases (\*.accx) for Windows users and as plain text tables (\*.csv) for Mac and Linux users.
#
# Survey methods and resulting data are very thoroughly documented in PDFs stored in the Access database zip file. For Guam, this is http://apps.fs.fed.us/fiadb-downloads/Databases/GUaccdb.zip.

# %% [markdown]
# ### Import libraries used in this script

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import sqlite3

# %% [markdown]
# ### Connect to SQLite DB

# %%
conn = sqlite3.connect('guam_forest_survey.db')

# %% [markdown]
# ### Test Queries
# Create dataframes containing the number of live trees (DBH >= 5 inches) observed in plots during the 2002 and 2013 surveys. Then merge these into a single dataframe.

# %% [markdown]
# ### 2002

# %%
sql = '''
select gu_tree.SPCD, GENUS, SPECIES, COMMON_NAME, count(*) as TREE_COUNT
from gu_tree, ref_species
where 
    INVYR = 2002
    and gu_tree.SPCD = ref_species.SPCD
    and DIA >= 5.0
    and STATUSCD = 1
group by gu_tree.SPCD
order by TREE_COUNT desc;
'''
df2002 = pd.read_sql(con=conn, sql=sql)
df2002
# Out:
#     SPCD         GENUS        SPECIES                  COMMON_NAME  TREE_COUNT
# 0   6852         Cycas     circinalis                   queen sago         108
# 1    908         Cocos       nucifera                 coconut palm          80
# 2   7377  Heterospathe          elata                  palma brava          73
# 3   7565      Leucaena   leucocephala               white leadtree          61
# 4   8874         Vitex     parviflora       smallflower chastetree          61
# 5   8085      Pandanus      tectorius           Tahitian screwpine          49
# 6   8307        Premna    obtusifolia                        ahgao          48
# 7   7412      Hibiscus      tiliaceus                 sea hibiscus          39
# 8   6042        Aglaia   mariannensis                      Titimel          20
# 9    885     Mangifera         indica                        mango          16
# 10  7627     Macaranga     thompsonii         Macaranga thompsonii          13
# 11  6459       Cerbera       dilatata                        chuti          11
# 12  7165         Ficus        prolixa                          aoa          10
# 13  7282        Guamia      mariannae                       paipai           9
# 14  7365     Hernandia        ovigera            Hernandia ovigera           9
# 15  6395        Carica         papaya                       papaya           8
# 16  6434     Casuarina  equisetifolia                 beach sheoak           8
# 17  6129        Annona     reticulata                custard apple           6
# 18  6171    Artocarpus        altilis                   breadfruit           6
# 19  7477        Intsia         bijuga                      ifilele           5
# 20  6028   Adenanthera       pavonina                 red beadtree           4
# 21  6197      Averrhoa        bilimbi                      Bilimbi           4
# 22  7506    Kleinhovia        hospita                   guest tree           4
# 23  7849       Morinda     citrifolia              Indian mulberry           4
# 24  8644     Spathodea    campanulata            African tuliptree           4
# 25  6167         Areca        catechu                     betelnut           3
# 26  6341   Calophyllum     inophyllum           Alexandrian laurel           3
# 27  8084      Pandanus           spp.                    screwpine           3
# 28  6220  Barringtonia       asiatica                    sea putat           2
# 29  6221  Barringtonia       racemosa                    langaasag           2
# 30  6840       Cyathea       lunulata                       olioli           2
# 31  7102       Eugenia     thompsonii                        atoto           2
# 32  7176         Ficus      tinctoria                         mati           2
# 33  7366     Hernandia         sonora                         mago           2
# 34  6175    Artocarpus   mariannensis  dugdug, Marianas breadfruit           1
# 35  6370       Cananga        odorata                  ilang-ilang           1
# 36  6449         Ceiba      pentandra                    kapoktree           1
# 37  7942   Neisosperma  oppositifolia                          fao           1
# 38  8909       Xylosma       nelsonii             Xylosma nelsonii           1

# %% [markdown]
# ### 2013

# %%
sql = '''
select gu_tree.SPCD, GENUS, SPECIES, COMMON_NAME, count(*) as TREE_COUNT
from gu_tree, ref_species
where 
    INVYR = 2013
    and gu_tree.SPCD = ref_species.SPCD
    and DIA >= 5.0
    and STATUSCD = 1
group by gu_tree.SPCD
order by TREE_COUNT desc;
'''
df2013 = pd.read_sql(con=conn, sql=sql)
df2013
# Out:
#     SPCD         GENUS          SPECIES                  COMMON_NAME  \
# 0   8874         Vitex       parviflora       smallflower chastetree
# 1    908         Cocos         nucifera                 coconut palm
# 2   7412      Hibiscus        tiliaceus                 sea hibiscus
# 3   7377  Heterospathe            elata                  palma brava
# 4   8085      Pandanus        tectorius           Tahitian screwpine
# 5   7565      Leucaena     leucocephala               white leadtree
# 6   8307        Premna      obtusifolia                        ahgao
# 7   6852         Cycas       circinalis                   queen sago
# 8   7942   Neisosperma    oppositifolia                          fao
# 9   6042        Aglaia     mariannensis                      Titimel
# 10   885     Mangifera           indica                        mango
# 11  6129        Annona       reticulata                custard apple
# 12  6434     Casuarina    equisetifolia                 beach sheoak
# 13  6167         Areca          catechu                     betelnut
# 14  7627     Macaranga       thompsonii         Macaranga thompsonii
# 15  8644     Spathodea      campanulata            African tuliptree
# 16  6341   Calophyllum       inophyllum           Alexandrian laurel
# 17  7165         Ficus          prolixa                          aoa
# 18  6197      Averrhoa          bilimbi                      Bilimbi
# 19  8213       Pisonia          grandis           grand devils-claws
# 20  6028   Adenanthera         pavonina                 red beadtree
# 21  6171    Artocarpus          altilis                   breadfruit
# 22  7849       Morinda       citrifolia              Indian mulberry
# 23  8846  Tristiropsis      obtusangula                         faia
# 24  7477        Intsia           bijuga                      ifilele
# 25  6370       Cananga          odorata                  ilang-ilang
# 26  7176         Ficus        tinctoria                         mati
# 27  7282        Guamia        mariannae                       paipai
# 28  6175    Artocarpus     mariannensis  dugdug, Marianas breadfruit
# 29  6220  Barringtonia         asiatica                    sea putat
# 30  7564      Leucaena        insularum           Leucaena insularum
# 31   999          Tree          unknown   Other or unknown live tree
# 32  6128        Annona         muricata                      soursop
# 33  6226      Bauhinia         monandra             Napoleon's plume
# 34  7654        Mammea          odorata                       chopak
# 35  8060      Pandanus           dubius                       pahong
# 36  6221  Barringtonia         racemosa                    langaasag
# 37  7088       Eugenia         palumbis                    agatelang
# 38  7248    Glochidion         marianum          Glochidion marianum
# 39  7366     Hernandia           sonora                         mago
# 40  7710   Melanolepis  multiglandulosa                         alom
# 41  8714      Tabebuia          pallida                pink tabebuia
#
#     TREE_COUNT
# 0          134
# 1          114
# 2          100
# 3           92
# 4           60
# 5           55
# 6           48
# 7           33
# 8           24
# 9           18
# 10          17
# 11          15
# 12          14
# 13          12
# 14          12
# 15          10
# 16           8
# 17           8
# 18           7
# 19           7
# 20           6
# 21           6
# 22           6
# 23           6
# 24           5
# 25           4
# 26           4
# 27           4
# 28           3
# 29           3
# 30           3
# 31           2
# 32           2
# 33           2
# 34           2
# 35           2
# 36           1
# 37           1
# 38           1
# 39           1
# 40           1
# 41           1

# %% [markdown]
# ### Merge 2002 and 2013 Data

# %%
df = pd.merge(df2002, df2013, on=['SPCD','GENUS','SPECIES','COMMON_NAME'], how='outer', suffixes=['_2002','_2013'])
# Convert NaNs to 0 and convert from float to integer
df['TREE_COUNT_2002'] = df['TREE_COUNT_2002'].fillna(0.0).astype(int)
df['TREE_COUNT_2013'] = df['TREE_COUNT_2013'].fillna(0.0).astype(int) 
df
# Out:
#       SPCD         GENUS          SPECIES                  COMMON_NAME  \
# 0   6852.0         Cycas       circinalis                   queen sago
# 1    908.0         Cocos         nucifera                 coconut palm
# 2   7377.0  Heterospathe            elata                  palma brava
# 3   7565.0      Leucaena     leucocephala               white leadtree
# 4   8874.0         Vitex       parviflora       smallflower chastetree
# 5   8085.0      Pandanus        tectorius           Tahitian screwpine
# 6   8307.0        Premna      obtusifolia                        ahgao
# 7   7412.0      Hibiscus        tiliaceus                 sea hibiscus
# 8   6042.0        Aglaia     mariannensis                      Titimel
# 9    885.0     Mangifera           indica                        mango
# 10  7627.0     Macaranga       thompsonii         Macaranga thompsonii
# 11  6459.0       Cerbera         dilatata                        chuti
# 12  7165.0         Ficus          prolixa                          aoa
# 13  7282.0        Guamia        mariannae                       paipai
# 14  7365.0     Hernandia          ovigera            Hernandia ovigera
# 15  6395.0        Carica           papaya                       papaya
# 16  6434.0     Casuarina    equisetifolia                 beach sheoak
# 17  6129.0        Annona       reticulata                custard apple
# 18  6171.0    Artocarpus          altilis                   breadfruit
# 19  7477.0        Intsia           bijuga                      ifilele
# 20  6028.0   Adenanthera         pavonina                 red beadtree
# 21  6197.0      Averrhoa          bilimbi                      Bilimbi
# 22  7506.0    Kleinhovia          hospita                   guest tree
# 23  7849.0       Morinda       citrifolia              Indian mulberry
# 24  8644.0     Spathodea      campanulata            African tuliptree
# 25  6167.0         Areca          catechu                     betelnut
# 26  6341.0   Calophyllum       inophyllum           Alexandrian laurel
# 27  8084.0      Pandanus             spp.                    screwpine
# 28  6220.0  Barringtonia         asiatica                    sea putat
# 29  6221.0  Barringtonia         racemosa                    langaasag
# 30  6840.0       Cyathea         lunulata                       olioli
# 31  7102.0       Eugenia       thompsonii                        atoto
# 32  7176.0         Ficus        tinctoria                         mati
# 33  7366.0     Hernandia           sonora                         mago
# 34  6175.0    Artocarpus     mariannensis  dugdug, Marianas breadfruit
# 35  6370.0       Cananga          odorata                  ilang-ilang
# 36  6449.0         Ceiba        pentandra                    kapoktree
# 37  7942.0   Neisosperma    oppositifolia                          fao
# 38  8909.0       Xylosma         nelsonii             Xylosma nelsonii
# 39  8213.0       Pisonia          grandis           grand devils-claws
# 40  8846.0  Tristiropsis      obtusangula                         faia
# 41  7564.0      Leucaena        insularum           Leucaena insularum
# 42   999.0          Tree          unknown   Other or unknown live tree
# 43  6128.0        Annona         muricata                      soursop
# 44  6226.0      Bauhinia         monandra             Napoleon's plume
# 45  7654.0        Mammea          odorata                       chopak
# 46  8060.0      Pandanus           dubius                       pahong
# 47  7088.0       Eugenia         palumbis                    agatelang
# 48  7248.0    Glochidion         marianum          Glochidion marianum
# 49  7710.0   Melanolepis  multiglandulosa                         alom
# 50  8714.0      Tabebuia          pallida                pink tabebuia
#
#     TREE_COUNT_2002  TREE_COUNT_2013
# 0               108               33
# 1                80              114
# 2                73               92
# 3                61               55
# 4                61              134
# 5                49               60
# 6                48               48
# 7                39              100
# 8                20               18
# 9                16               17
# 10               13               12
# 11               11                0
# 12               10                8
# 13                9                4
# 14                9                0
# 15                8                0
# 16                8               14
# 17                6               15
# 18                6                6
# 19                5                5
# 20                4                6
# 21                4                7
# 22                4                0
# 23                4                6
# 24                4               10
# 25                3               12
# 26                3                8
# 27                3                0
# 28                2                3
# 29                2                1
# 30                2                0
# 31                2                0
# 32                2                4
# 33                2                1
# 34                1                3
# 35                1                4
# 36                1                0
# 37                1               24
# 38                1                0
# 39                0                7
# 40                0                6
# 41                0                3
# 42                0                2
# 43                0                2
# 44                0                2
# 45                0                2
# 46                0                2
# 47                0                1
# 48                0                1
# 49                0                1
# 50                0                1

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
df.plot(
    ax=ax,
    title='Total number of trees with DBH >= 5 inches in all sample plots ',
    kind='barh',
    x=df.GENUS+' '+df.SPECIES+' ('+df.COMMON_NAME+')',
    y=['TREE_COUNT_2002','TREE_COUNT_2013'],
    figsize=(10, 20),
    width=0.8,
    color=['black','gray'],
    ylim=(0,150),
    legend=False,
).invert_yaxis()
ax.legend(["2002", "2013"]);
